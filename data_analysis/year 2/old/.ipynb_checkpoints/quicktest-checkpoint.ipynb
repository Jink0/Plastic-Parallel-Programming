# %% [markdown]
# # Experiment 1 - Common use case, optimizing N threads

# %%
# Import packages
from __future__ import division, print_function # Imports from __future__ since we're running Python 2
import os
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %run '/home/mark/Desktop/Plastic-Parallel-Programming/data_analysis/year 2/utilities.ipynb'

# %% [markdown]
# Program parameters:

# %%
folder_path1    = 'results/quicktest/'
number_of_runs  = 1
number_of_tests = 108

# %% [markdown]
# Set files to read

# %%
file_names = []

for i in range(1, number_of_tests + 1): 
    file_names.append("test" + str(i) + "/output")

# %% [markdown]
# Import the dataset

# %%
data = []
        
fetch_data(folder_path1, file_names, data, ["Runtime"])
        
dataset = []

powers_min = 8
powers_max = 11
num_workers_min = 8
num_workers_max = 32
num_workers_step = 8
workloads = ["BASIC_KERNEL_SMALL", "BASIC_KERNEL_LARGE", "none", "addpd", "mulpd", "sqrt", "compute", "shared_mem_read_small", "shared_mem_read_large"]
workload = 0

power = powers_min
num_workers = num_workers_min

for i in range(len(data)):
    dataset.append([2 ** power, num_workers, data[i].mean()[0], workloads[workload]])
    
    if num_workers == num_workers_max:
        num_workers_step = 8
        if power == powers_max:
            workload = workload + 1
            num_workers = num_workers_min
            power = powers_min
        else:
            num_workers = num_workers_min
            power = power + 1
    else:
        num_workers = num_workers + num_workers_step
        num_workers_step = num_workers_step + num_workers_step

dataset = pd.DataFrame(dataset)
dataset.columns = ["Grid Size", "Num Workers", "Time", "Workload"]

dataset
# Out:
#      Grid Size  Num Workers     Time               Workload
# 0          256            8      4.0     BASIC_KERNEL_SMALL
# 1          256           16     15.0     BASIC_KERNEL_SMALL
# 2          256           32     43.0     BASIC_KERNEL_SMALL
# 3          512            8      7.0     BASIC_KERNEL_SMALL
# 4          512           16     19.0     BASIC_KERNEL_SMALL
# 5          512           32     44.0     BASIC_KERNEL_SMALL
# 6         1024            8     27.0     BASIC_KERNEL_SMALL
# 7         1024           16     33.0     BASIC_KERNEL_SMALL
# 8         1024           32     62.0     BASIC_KERNEL_SMALL
# 9         2048            8    203.0     BASIC_KERNEL_SMALL
# 10        2048           16    100.0     BASIC_KERNEL_SMALL
# 11        2048           32     65.0     BASIC_KERNEL_SMALL
# 12         256            8      8.0     BASIC_KERNEL_LARGE
# 13         256           16     21.0     BASIC_KERNEL_LARGE
# 14         256           32     46.0     BASIC_KERNEL_LARGE
# 15         512            8     23.0     BASIC_KERNEL_LARGE
# 16         512           16     17.0     BASIC_KERNEL_LARGE
# 17         512           32     73.0     BASIC_KERNEL_LARGE
# 18        1024            8     96.0     BASIC_KERNEL_LARGE
# 19        1024           16     50.0     BASIC_KERNEL_LARGE
# 20        1024           32     59.0     BASIC_KERNEL_LARGE
# 21        2048            8    364.0     BASIC_KERNEL_LARGE
# 22        2048           16    188.0     BASIC_KERNEL_LARGE
# 23        2048           32    178.0     BASIC_KERNEL_LARGE
# 24         256            8     13.0                   none
# 25         256           16     17.0                   none
# 26         256           32     54.0                   none
# 27         512            8     34.0                   none
# 28         512           16     29.0                   none
# 29         512           32     39.0                   none
# ..         ...          ...      ...                    ...
# 78        1024            8   7786.0                compute
# 79        1024           16   4316.0                compute
# 80        1024           32   2535.0                compute
# 81        2048            8  18548.0                compute
# 82        2048           16  12319.0                compute
# 83        2048           32   7865.0                compute
# 84         256            8    351.0  shared_mem_read_small
# 85         256           16    229.0  shared_mem_read_small
# 86         256           32    188.0  shared_mem_read_small
# 87         512            8   1600.0  shared_mem_read_small
# 88         512           16    832.0  shared_mem_read_small
# 89         512           32    530.0  shared_mem_read_small
# 90        1024            8   4035.0  shared_mem_read_small
# 91        1024           16   2946.0  shared_mem_read_small
# 92        1024           32   1512.0  shared_mem_read_small
# 93        2048            8  22456.0  shared_mem_read_small
# 94        2048           16   9948.0  shared_mem_read_small
# 95        2048           32   6888.0  shared_mem_read_small
# 96         256            8    598.0  shared_mem_read_large
# 97         256           16    323.0  shared_mem_read_large
# 98         256           32    221.0  shared_mem_read_large
# 99         512            8   2356.0  shared_mem_read_large
# 100        512           16   1210.0  shared_mem_read_large
# 101        512           32    789.0  shared_mem_read_large
# 102       1024            8   5831.0  shared_mem_read_large
# 103       1024           16   2787.0  shared_mem_read_large
# 104       1024           32   2409.0  shared_mem_read_large
# 105       2048            8  24161.0  shared_mem_read_large
# 106       2048           16  12247.0  shared_mem_read_large
# 107       2048           32   6910.0  shared_mem_read_large
#
# [108 rows x 4 columns]

# %%
sns.factorplot(x="Num Workers", y="Time",
               col="Workload",
               hue="Grid Size",
               data=dataset);
plt.savefig("graphs/quicktest/quicktest.png")
plt.show()
