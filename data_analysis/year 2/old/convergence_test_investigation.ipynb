# %% [markdown]
# # Experiment 1 - Common use case, optimizing N threads

# %%
# Import packages
from __future__ import division, print_function # Imports from __future__ since we're running Python 2
import os
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %run '/home/mark/Desktop/Plastic-Parallel-Programming/data_analysis/year 2/utilities.ipynb'

# %% [markdown]
# Program parameters:

# %%
folder_path1    = 'results/convergence_test_investigation/'
number_of_tests = 84

# %% [markdown]
# Set files to read

# %%
file_names = []

for i in range(1, number_of_tests + 1): 
    file_names.append("test" + str(i) + "/output")

# %% [markdown]
# Import the dataset

# %%
data = []
        
fetch_data(folder_path1, file_names, data, ["Runtime"])
        
dataset = []

power = 10
num_workers = 4
convergence = False

for i in range(len(data)):
    dataset.append([2 ** power, num_workers, data[i].mean()[0], convergence])
    
    if num_workers == 32:
        if power == 15:
            convergence = True
            num_workers = 4
            power = 10
        else:
            num_workers = 4
            power = power + 1
    else:
        num_workers = num_workers + 4

dataset = pd.DataFrame(dataset)
dataset.columns = ["Grid Size", "Num Workers", "Time", "Convergence Test"]

conv_false = dataset.loc[dataset['Convergence Test'] == False]
conv_true  = dataset.loc[dataset['Convergence Test'] == True]

dataset
# Out:
#     Grid Size  Num Workers    Time  Convergence Test
# 0        1024            4     3.2             False
# 1        1024            8     3.2             False
# 2        1024           12     3.8             False
# 3        1024           16     3.4             False
# 4        1024           20     3.8             False
# 5        1024           24     4.6             False
# 6        1024           28     5.4             False
# 7        1024           32     9.0             False
# 8        2048            4     6.8             False
# 9        2048            8     6.8             False
# 10       2048           12     6.2             False
# 11       2048           16     6.2             False
# 12       2048           20     6.6             False
# 13       2048           24     6.6             False
# 14       2048           28    79.8             False
# 15       2048           32    81.4             False
# 16       4096            4    82.6             False
# 17       4096            8    84.6             False
# 18       4096           12    87.6             False
# 19       4096           16    68.2             False
# 20       4096           20    93.2             False
# 21       4096           24   196.0             False
# 22       4096           28   156.0             False
# 23       4096           32   141.0             False
# 24       8192            4   133.0             False
# 25       8192            8   123.0             False
# 26       8192           12   134.0             False
# 27       8192           16   127.8             False
# 28       8192           20   922.6             False
# 29       8192           24   784.6             False
# ..        ...          ...     ...               ...
# 54       1024           28     7.6              True
# 55       1024           32     7.6              True
# 56       2048            4    94.0              True
# 57       2048            8   103.0              True
# 58       2048           12    64.2              True
# 59       2048           16    54.6              True
# 60       2048           20    52.0              True
# 61       2048           24    51.8              True
# 62       2048           28    51.6              True
# 63       2048           32   340.6              True
# 64       4096            4   240.8              True
# 65       4096            8   204.0              True
# 66       4096           12   182.4              True
# 67       4096           16   163.8              True
# 68       4096           20   159.6              True
# 69       4096           24   170.0              True
# 70       4096           28  1456.8              True
# 71       4096           32  1081.8              True
# 72       8192            4   912.4              True
# 73       8192            8   843.8              True
# 74       8192           12   815.2              True
# 75       8192           16   680.8              True
# 76       8192           20   734.4              True
# 77       8192           24  6105.8              True
# 78       8192           28  4252.6              True
# 79       8192           32  3660.4              True
# 80      16384            4  3134.8              True
# 81      16384            8  3423.8              True
# 82      16384           12  2962.2              True
# 83      16384           16  2913.6              True
#
# [84 rows x 4 columns]

# %%
for i in range(0, 6):
    test = conv_true.loc[conv_true['Grid Size'] == 2 ** (10 + i)]
    plt.plot(test["Num Workers"], test["Time"], label=str(2 ** (10 + i)) + " - True")
    test = conv_false.loc[conv_false['Grid Size'] == 2 ** (10 + i)]
    plt.plot(test["Num Workers"], test["Time"], label=str(2 ** (10 + i)) + " - False")
    plt.legend(loc='best')
    plt.savefig("graphs/convergence_test/" + str(2 ** (10 + i)) + ".png")
    plt.show()
